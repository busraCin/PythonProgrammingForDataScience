# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
df[17:20]
#seçme işlemleri
# Out:
#     survived  pclass     sex   age  sibsp  parch    fare embarked   class  \
# 17         1       2    male   NaN      0      0  13.000        S  Second
# 18         0       3  female  31.0      1      0  18.000        S   Third
# 19         1       3  female   NaN      0      0   7.225        C   Third
#
#       who  adult_male deck  embark_town alive  alone
# 17    man        True  NaN  Southampton   yes   True
# 18  woman       False  NaN  Southampton    no  False
# 19  woman       False  NaN    Cherbourg   yes   True

# %%
#drop ile silme işlemi yapılır
df.drop(2,axis=0).head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 3  woman       False    C  Southampton   yes  False

# %%
del_list = [1,3,4,5]
df.drop(del_list,axis=0, inplace=True)
df.head()
#silme işlemini kalıcı yapmak için df yi tekrar atarız veya inplace argümanını True yaparız
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
# 7         0       3    male   2.0      3      1  21.0750        S  Third
# 8         1       3  female  27.0      0      2  11.1333        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 2  woman       False  NaN  Southampton   yes   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False

# %%
#değişkeni indexe çevirmek
df.index = df["age"] #yaş bilgisi değişken olarak indexe gelir
df.index
# Out:
# Float64Index([22.0, 26.0, 54.0,  2.0, 27.0, 14.0,  4.0, 58.0, 20.0, 39.0,
#               ...
#               33.0, 22.0, 28.0, 25.0, 39.0, 27.0, 19.0,  nan, 26.0, 32.0],
#              dtype='float64', name='age', length=887)

# %%
#indexi değişkene çevirme
df["age2"] = df.index #age2 yeni bir değişken olarak eklendi
df.head(3)
#2. yol reset_index() kullanmaktır. df = df.reset_index
# Out:
#       survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# age
# 22.0         0       3    male  22.0      1      0   7.2500        S  Third
# 26.0         1       3  female  26.0      0      0   7.9250        S  Third
# 54.0         0       1    male  54.0      0      0  51.8625        S  First
#
#         who  adult_male deck  embark_town alive  alone  age2
# age
# 22.0    man        True  NaN  Southampton    no  False  22.0
# 26.0  woman       False  NaN  Southampton   yes   True  26.0
# 54.0    man        True    E  Southampton    no   True  54.0
